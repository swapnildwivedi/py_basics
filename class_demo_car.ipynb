# %% [markdown]
# <a href="https://colab.research.google.com/github/swapnildwivedi/py_basics/blob/main/class_demo_car.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class car:
    def __init__(self , color , model):
        self.color = color
        self.model = model

    def start(self):
        print(f"Your {self.color} {self.model} is ready to launch")


car_1 = car('Red' , 'BMW')

car_1.start()
# Out:
# Your Red BMW is ready to launch
